# %% [markdown]
# # Predict Seagrass at different times
# * Designed to work year by year
# * Pick a location and run

# %%
import geopandas
import pathlib
import rioxarray
import numpy
import dask.distributed
import pandas
import rasterio

module_path = pathlib.Path.cwd().parent / 'scripts'
import sys
if str(module_path) not in sys.path:
    sys.path.append(str(module_path))
import utils
import sentinel2
import training
import sampling

# %load_ext autoreload
# %autoreload 2

# %%
cluster = dask.distributed.LocalCluster()
client = dask.distributed.Client(cluster)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:59685' processes=4 threads=8, memory=31.73 GiB>

# %% [markdown]
# # Value to edit

# %%
all_training_sites =  ["CatlinsLake", "CatlinsRiverMouth", "Childrens", "Duvauchelle", "Robinsons", "Takamatua", "Purau", "Ihutai",
              "IveyBay_Nov25", "IveyBay_Feb26", "LeftBank_Nov25", "LeftBank_Feb26", "Paremata_Nov25", "Paremata_Feb26",
              "Paremata_Feb25", "ThePoint_Nov25", "ThePoint_Feb26", "Takapuwahia_Nov25", "Takapuwahia_Feb26", "IveyBay_ThePoint_LeftBank_Oct24"]
large_seagrass_sites =  ["CatlinsRiverMouth", "Childrens", "Duvauchelle", "Robinsons", "Ihutai", "LeftBank_Nov25", "ThePoint_Nov25"]

# %%
satellite_classes_all = {'Seagrass': 1, 'Seagrass submerged': 2, 'Gracilaria': 3, 'Gracilaria submerged': 4, 
                           'Ulva': 5, 'Submerged vegetation': 9, 'Microphytobenthos': 10, 'Satmarsh': 14,
                           'Unvegetated': 15, 'Water': 16, 'Terrestrial': 18, 'Rock': 19, 'Mixed': 22,}
satellite_classes_all_unet = {'Seagrass': 0, 'Seagrass submerged': 1, 'Gracilaria': 2, 'Gracilaria submerged': 3, 
                           'Ulva': 4, 'Submerged vegetation': 5, 'Microphytobenthos': 6, 'Satmarsh': 7,
                           'Unvegetated': 8, 'Water': 9, 'Terrestrial': 10, 'Rock': 11, 'Mixed': 12,}

# %%
sample_method = "sampling_2"
method_2_threshold = .5
model_max_cloud_cover = 10 # percentage
model_low_tide_delta_hrs = 0
model_low_tide_delta_mins = 30
test_threshold = 0.1

predict_max_cloud_cover = 1 # percentage"
predict_low_tide_delta_hrs = 0
predict_low_tide_delta_mins = 30

model_name = f"test_on_{int(test_threshold*100)}_percent_all_classes.joblib"

# %%
model_path = utils.get_models_path(sample_method=sample_method, method_2_threshold=method_2_threshold,
                                   low_tide_delta_hrs=model_low_tide_delta_hrs, low_tide_delta_mins=model_low_tide_delta_mins,
                                   max_cloud_cover=model_max_cloud_cover)
model_file = model_path / model_name
prediction_sites = large_seagrass_sites
years = [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]

# %%
data_path = utils.get_data_path()
utils.create_data_folders()
predictions_path, satellite_path = utils.get_prediction_path(sample_method, method_2_threshold, model_max_cloud_cover=model_max_cloud_cover, predict_max_cloud_cover=predict_max_cloud_cover,
                                             predict_low_tide_delta_hrs=predict_low_tide_delta_hrs, predict_low_tide_delta_mins=predict_low_tide_delta_mins,
                                             model_low_tide_delta_hrs=model_low_tide_delta_hrs, model_low_tide_delta_mins=model_low_tide_delta_mins)

# %% [markdown]
# # Cells to run
# * Get lowtide satellite images by year and site
# * Predict Seagrass across satellite images

# %% [markdown]
# ### Save satellite
# The low-tide no cloud images across sites for a whole year

# %%
for prediction_site in prediction_sites:
    for year in years:
        print(f"{prediction_site}: year {year}")
    
        satellite_file = satellite_path / f"{prediction_site}_{year}_sentinel-2.nc"
        site_polygon_file = utils.get_site_polygon_path(prediction_site)
    
        if not satellite_file.exists():
            print(f"\tSave satellite image of the site {prediction_site} around lowtide without cloud in the year {year}")
            site_polygon = geopandas.read_file(site_polygon_file)
            satellite_data = sentinel2.get_low_tide_no_cloud_images_in_year(
                geometry=site_polygon,
                max_cloud_cover=predict_max_cloud_cover,
                year=year,
                low_tide_delta_hrs=predict_low_tide_delta_hrs,
                low_tide_delta_mins=predict_low_tide_delta_mins,
            )
            if len(satellite_data['time']) == 0:
                print("Warning: No satellite data without cloud. Ignore")
            else:
                print("\t\tSave")
                utils.write_netcdf_conventions_in_place(satellite_data)
                satellite_data = satellite_data.rio.reproject(utils.CRS_NZTM)
                satellite_data = satellite_data.rio.clip(site_polygon.geometry, drop=True, all_touched=True)
                utils.write_netcdf_conventions_in_place(satellite_data)
                utils.save_netcdf(satellite_data, satellite_file)
            utils.rgb_from_satellite(satellite_data_path=satellite_file)
# Out:
# CatlinsRiverMouth: year 2016
# CatlinsRiverMouth: year 2017
# 	Save satellite image of the site CatlinsRiverMouth around lowtide without cloud in the year 2017
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 11
#       7
#       8         if not satellite_file.exists():
#       9             print(f"\tSave satellite image of the site {prediction_site} around lowtide without cloud in the year {year}")
#      10             site_polygon = geopandas.read_file(site_polygon_file)
# ---> 11             satellite_data = sentinel2.get_low_tide_no_cloud_images_in_year(
#      12                 geometry=site_polygon,
#      13                 max_cloud_cover=predict_max_cloud_cover,
#      14                 year=year,
#
# File C:\Local\repos\seagrass-detection\scripts\sentinel2.py:290, in get_low_tide_no_cloud_images_in_year(geometry, max_cloud_cover, year, low_tide_delta_hrs, low_tide_delta_mins)
#     286 def get_low_tide_no_cloud_images_in_year(
#     287     geometry, max_cloud_cover, year: int, low_tide_delta_hrs: int, low_tide_delta_mins: int
#     288 ):
# --> 290     data = get_low_tide_images_in_year(geometry, year, low_tide_delta_hrs=low_tide_delta_hrs,
#     291                                        low_tide_delta_mins=low_tide_delta_mins)
#     292     number_of_low_tide_dates = len(data["time"])
#     294     # keep only values with less cloud cover than the specified percentatge
#
# File C:\Local\repos\seagrass-detection\scripts\sentinel2.py:194, in get_low_tide_images_in_year(geometry, year, low_tide_delta_hrs, low_tide_delta_mins)
#     191 low_tide = []
#     192 for item in items:
#     193     low_tide.append(
# --> 194         check_low_tide(item, lat=lat, lon=lon, low_tide_delta_hrs=low_tide_delta_hrs,
#     195                        low_tide_delta_mins=low_tide_delta_mins)
#     196     )
#     198 items = [item for item, low_tide in zip(items, low_tide) if low_tide]
#     200 # Keep all near lowtide and keep only those with no cloud cover
#
# File C:\Local\repos\seagrass-detection\scripts\sentinel2.py:376, in check_low_tide(item, lat, lon, low_tide_delta_hrs, low_tide_delta_mins)
#     374 for attempt in range(1, 3):
#     375     try:
# --> 376         tide_query = requests.get(tide_url)
#     377         tide_query.raise_for_status()
#     378         break
#
# File ~\.conda\envs\seagrass\Lib\site-packages\requests\api.py:87, in get(url, params, **kwargs)
#      74 def get(
#      75     url: _t.UriType, params: _t.ParamsType = None, **kwargs: Unpack[_t.GetKwargs]
#      76 ) -> Response:
#      77     r"""Sends a GET request.
#      78
#      79     :param url: URL for the new :class:`Request` object.
#    (...)     84     :rtype: requests.Response
#      85     """
# ---> 87     return request("get", url, params=params, **kwargs)
#
# File ~\.conda\envs\seagrass\Lib\site-packages\requests\api.py:71, in request(method, url, **kwargs)
#      67 # By using the 'with' statement we are sure the session is closed, thus we
#      68 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      69 # cases, and look like a memory leak in others.
#      70 with sessions.Session() as session:
# ---> 71     return session.request(method=method, url=url, **kwargs)
#
# File ~\.conda\envs\seagrass\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File ~\.conda\envs\seagrass\Lib\site-packages\requests\sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File ~\.conda\envs\seagrass\Lib\site-packages\requests\adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     693     resolved_timeout = TimeoutSauce(connect=timeout, read=timeout)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#     711     raise ConnectionError(err, request=request)
#
# File ~\.conda\envs\seagrass\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785 response_conn = conn if not release_conn else None
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#     804 clean_exit = True
#
# File ~\.conda\envs\seagrass\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\.conda\envs\seagrass\Lib\site-packages\urllib3\connectionpool.py:1106, in HTTPSConnectionPool._validate_conn(self, conn)
#    1104 # Force connect early to allow us to validate the connection.
#    1105 if conn.is_closed:
# -> 1106     conn.connect()
#    1108 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1109 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~\.conda\envs\seagrass\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     757 try:
#     758     sock: socket.socket | ssl.SSLSocket
# --> 759     self.sock = sock = self._new_conn()
#     760     server_hostname: str = self.host
#     761     tls_in_tls = False
#
# File ~\.conda\envs\seagrass\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File ~\.conda\envs\seagrass\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %% [markdown]
# ### Predict values

# %%
for prediction_site in prediction_sites:
    for year in years:
        print(f"{prediction_site}: year {year}")
        prediction_file = predictions_path / f"{prediction_site}_{year}_model_{model_file.stem}.nc"
        polygon_file = utils.get_site_polygon_path(prediction_site)
        satellite_file = satellite_path / f"{prediction_site}_{year}_sentinel-2.nc"
        
        if not prediction_file.exists():
            model_feature_names_file = model_file.with_name(f"{model_file.stem}_feature_names.csv")
            if not satellite_file.exists():
                print("\tWARNING no satellite file to predict. Rerun the above cell if this is unexpected."
                      " Otherwise this indicates no suitable low-tide and low-cloud dates in the year.")
                continue
            predictions, satellite_data = training.predict_site(test_satellite_file=satellite_file,
                                                                polygon_file=polygon_file, model_file=model_file,
                                                                model_feature_names_file=model_feature_names_file)
            utils.save_netcdf(predictions, prediction_file)
        else:
            predictions = utils.load_classification(filename=prediction_file, chunks=None)
    
        for target_name in ["Seagrass", "Ulva", "Gracilaria"]:
            target_file = predictions_path /  f"{prediction_site}_{year}_model_{model_file.stem}_{target_name.lower()}.gpkg"
            if not target_file.exists():
                target = {"date": [], "geometry": []}
                prediction = utils.load_classification(filename=prediction_file)
                prediction = utils.ensure_grid_indexing(prediction)
                target_id = pandas.read_csv(model_file.with_name(f"{model_file.stem}_class_mappings.csv"), index_col=0)
                target_id = int(target_id.loc[target_id.index == target_name,"satellite_class_id"].squeeze())
                for time_index in range(len(prediction["time"])):
                    mask = predictions.isel(time=time_index) == target_id
                    target["date"].append(str(mask.time.data))
                    geometry = utils.mask_to_polygons(mask).dissolve().geometry
                    target["geometry"].append(geometry[0])
                target = geopandas.GeoDataFrame(target, crs="2193")
                target.to_file(target_file)
# Out:
# CatlinsRiverMouth: year 2016
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2016-04-09
# 	Combine predictions and write conventions
# CatlinsRiverMouth: year 2017
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# CatlinsRiverMouth: year 2018
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2018-04-02
# 	Combine predictions and write conventions
# CatlinsRiverMouth: year 2019
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2019-02-21
# 	Predict satellite image for date 2019-04-07
# 	Predict satellite image for date 2019-08-17
# 	Combine predictions and write conventions
# CatlinsRiverMouth: year 2020
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2020-11-02
# 	Predict satellite image for date 2020-12-02
# 	Combine predictions and write conventions
# CatlinsRiverMouth: year 2021
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# CatlinsRiverMouth: year 2022
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2022-07-15
# 	Predict satellite image for date 2022-12-09
# 	Predict satellite image for date 2022-12-24
# 	Combine predictions and write conventions
# CatlinsRiverMouth: year 2023
# 	Predict for 5 satellite images
# 	Predict satellite image for date 2023-01-08
# 	Predict satellite image for date 2023-04-08
# 	Predict satellite image for date 2023-06-20
# 	Predict satellite image for date 2023-07-20
# 	Predict satellite image for date 2023-12-14
# 	Combine predictions and write conventions
# CatlinsRiverMouth: year 2024
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# CatlinsRiverMouth: year 2025
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2025-08-25
# 	Combine predictions and write conventions
# CatlinsRiverMouth: year 2026
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2026-02-19
# 	Predict satellite image for date 2026-06-16
# 	Combine predictions and write conventions
# Childrens: year 2016
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2016-05-06
# 	Predict satellite image for date 2016-06-05
# 	Predict satellite image for date 2016-11-15
# 	Combine predictions and write conventions
# Childrens: year 2017
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2017-02-10
# 	Combine predictions and write conventions
# Childrens: year 2018
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2018-04-16
# 	Predict satellite image for date 2018-07-13
# 	Combine predictions and write conventions
# Childrens: year 2019
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2019-01-21
# 	Predict satellite image for date 2019-05-19
# 	Predict satellite image for date 2019-07-03
# 	Combine predictions and write conventions
# Childrens: year 2020
# 	Predict for 7 satellite images
# 	Predict satellite image for date 2020-02-23
# 	Predict satellite image for date 2020-03-24
# 	Predict satellite image for date 2020-04-23
# 	Predict satellite image for date 2020-09-02
# 	Predict satellite image for date 2020-09-17
# 	Predict satellite image for date 2020-10-17
# 	Predict satellite image for date 2020-12-14
# 	Combine predictions and write conventions
# Childrens: year 2021
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2021-10-20
# 	Predict satellite image for date 2021-12-19
# 	Combine predictions and write conventions
# Childrens: year 2022
# 	Predict for 4 satellite images
# 	Predict satellite image for date 2022-04-30
# 	Predict satellite image for date 2022-05-30
# 	Predict satellite image for date 2022-06-14
# 	Predict satellite image for date 2022-10-10
# 	Combine predictions and write conventions
# Childrens: year 2023
# 	Predict for 6 satellite images
# 	Predict satellite image for date 2023-03-06
# 	Predict satellite image for date 2023-06-04
# 	Predict satellite image for date 2023-08-16
# 	Predict satellite image for date 2023-08-31
# 	Predict satellite image for date 2023-09-30
# 	Predict satellite image for date 2023-10-15
# 	Combine predictions and write conventions
# Childrens: year 2024
# 	Predict for 5 satellite images
# 	Predict satellite image for date 2024-06-06
# 	Predict satellite image for date 2024-07-06
# 	Predict satellite image for date 2024-08-05
# 	Predict satellite image for date 2024-08-20
# 	Predict satellite image for date 2024-11-30
# 	Combine predictions and write conventions
# Childrens: year 2025
# 	Predict for 7 satellite images
# 	Predict satellite image for date 2025-02-28
# 	Predict satellite image for date 2025-04-12
# 	Predict satellite image for date 2025-05-12
# 	Predict satellite image for date 2025-07-11
# 	Predict satellite image for date 2025-09-21
# 	Predict satellite image for date 2025-10-21
# 	Predict satellite image for date 2025-12-05
# 	Combine predictions and write conventions
# Childrens: year 2026
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2026-02-01
# 	Predict satellite image for date 2026-04-02
# 	Predict satellite image for date 2026-05-02
# 	Combine predictions and write conventions
# Duvauchelle: year 2016
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2016-05-06
# 	Combine predictions and write conventions
# Duvauchelle: year 2017
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2017-02-10
# 	Predict satellite image for date 2017-07-23
# 	Combine predictions and write conventions
# Duvauchelle: year 2018
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2018-04-16
# 	Predict satellite image for date 2018-07-13
# 	Predict satellite image for date 2018-07-28
# 	Combine predictions and write conventions
# Duvauchelle: year 2019
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2019-05-19
# 	Predict satellite image for date 2019-07-03
# 	Combine predictions and write conventions
# Duvauchelle: year 2020
# 	Predict for 7 satellite images
# 	Predict satellite image for date 2020-02-23
# 	Predict satellite image for date 2020-03-24
# 	Predict satellite image for date 2020-04-23
# 	Predict satellite image for date 2020-09-02
# 	Predict satellite image for date 2020-09-17
# 	Predict satellite image for date 2020-10-17
# 	Predict satellite image for date 2020-12-14
# 	Combine predictions and write conventions
# Duvauchelle: year 2021
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2021-12-19
# 	Combine predictions and write conventions
# Duvauchelle: year 2022
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2022-04-30
# 	Predict satellite image for date 2022-10-10
# 	Combine predictions and write conventions
# Duvauchelle: year 2023
# 	Predict for 5 satellite images
# 	Predict satellite image for date 2023-03-06
# 	Predict satellite image for date 2023-07-17
# 	Predict satellite image for date 2023-08-31
# 	Predict satellite image for date 2023-09-30
# 	Predict satellite image for date 2023-10-15
# 	Combine predictions and write conventions
# Duvauchelle: year 2024
# 	Predict for 5 satellite images
# 	Predict satellite image for date 2024-06-06
# 	Predict satellite image for date 2024-07-06
# 	Predict satellite image for date 2024-08-05
# 	Predict satellite image for date 2024-08-20
# 	Predict satellite image for date 2024-11-30
# 	Combine predictions and write conventions
# Duvauchelle: year 2025
# 	Predict for 7 satellite images
# 	Predict satellite image for date 2025-02-28
# 	Predict satellite image for date 2025-04-12
# 	Predict satellite image for date 2025-05-12
# 	Predict satellite image for date 2025-07-11
# 	Predict satellite image for date 2025-09-21
# 	Predict satellite image for date 2025-10-21
# 	Predict satellite image for date 2025-12-05
# 	Combine predictions and write conventions
# Duvauchelle: year 2026
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2026-02-01
# 	Predict satellite image for date 2026-04-02
# 	Predict satellite image for date 2026-05-02
# 	Combine predictions and write conventions
# Robinsons: year 2016
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2016-05-06
# 	Combine predictions and write conventions
# Robinsons: year 2017
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2017-02-10
# 	Predict satellite image for date 2017-07-23
# 	Combine predictions and write conventions
# Robinsons: year 2018
# 	Predict for 4 satellite images
# 	Predict satellite image for date 2018-04-16
# 	Predict satellite image for date 2018-07-13
# 	Predict satellite image for date 2018-07-28
# 	Predict satellite image for date 2018-12-22
# 	Combine predictions and write conventions
# Robinsons: year 2019
# 	Predict for 4 satellite images
# 	Predict satellite image for date 2019-01-21
# 	Predict satellite image for date 2019-05-19
# 	Predict satellite image for date 2019-06-03
# 	Predict satellite image for date 2019-07-03
# 	Combine predictions and write conventions
# Robinsons: year 2020
# 	Predict for 8 satellite images
# 	Predict satellite image for date 2020-02-23
# 	Predict satellite image for date 2020-03-24
# 	Predict satellite image for date 2020-04-08
# 	Predict satellite image for date 2020-04-23
# 	Predict satellite image for date 2020-09-02
# 	Predict satellite image for date 2020-09-17
# 	Predict satellite image for date 2020-10-17
# 	Predict satellite image for date 2020-12-14
# 	Combine predictions and write conventions
# Robinsons: year 2021
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2021-12-19
# 	Combine predictions and write conventions
# Robinsons: year 2022
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2022-04-30
# 	Predict satellite image for date 2022-10-10
# 	Combine predictions and write conventions
# Robinsons: year 2023
# 	Predict for 6 satellite images
# 	Predict satellite image for date 2023-03-06
# 	Predict satellite image for date 2023-06-04
# 	Predict satellite image for date 2023-07-17
# 	Predict satellite image for date 2023-08-31
# 	Predict satellite image for date 2023-09-30
# 	Predict satellite image for date 2023-10-15
# 	Combine predictions and write conventions
# Robinsons: year 2024
# 	Predict for 5 satellite images
# 	Predict satellite image for date 2024-06-06
# 	Predict satellite image for date 2024-07-06
# 	Predict satellite image for date 2024-08-05
# 	Predict satellite image for date 2024-08-20
# 	Predict satellite image for date 2024-11-30
# 	Combine predictions and write conventions
# Robinsons: year 2025
# 	Predict for 5 satellite images
# 	Predict satellite image for date 2025-02-28
# 	Predict satellite image for date 2025-05-12
# 	Predict satellite image for date 2025-07-11
# 	Predict satellite image for date 2025-09-21
# 	Predict satellite image for date 2025-10-21
# 	Combine predictions and write conventions
# Robinsons: year 2026
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2026-02-01
# 	Predict satellite image for date 2026-04-02
# 	Predict satellite image for date 2026-05-02
# 	Combine predictions and write conventions
# Ihutai: year 2016
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2016-04-06
# 	Predict satellite image for date 2016-05-06
# 	Predict satellite image for date 2016-09-16
# 	Combine predictions and write conventions
# Ihutai: year 2017
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# Ihutai: year 2018
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2018-03-30
# 	Predict satellite image for date 2018-05-29
# 	Combine predictions and write conventions
# Ihutai: year 2019
# 	Predict for 4 satellite images
# 	Predict satellite image for date 2019-01-04
# 	Predict satellite image for date 2019-02-03
# 	Predict satellite image for date 2019-03-05
# 	Predict satellite image for date 2019-12-25
# 	Combine predictions and write conventions
# Ihutai: year 2020
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2020-10-30
# 	Predict satellite image for date 2020-12-14
# 	Combine predictions and write conventions
# Ihutai: year 2021
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2021-09-20
# 	Predict satellite image for date 2021-10-20
# 	Combine predictions and write conventions
# Ihutai: year 2022
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2022-08-26
# 	Combine predictions and write conventions
# Ihutai: year 2023
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2023-07-17
# 	Predict satellite image for date 2023-08-01
# 	Combine predictions and write conventions
# Ihutai: year 2024
# 	Predict for 4 satellite images
# 	Predict satellite image for date 2024-02-22
# 	Predict satellite image for date 2024-04-22
# 	Predict satellite image for date 2024-05-07
# 	Predict satellite image for date 2024-06-06
# 	Combine predictions and write conventions
# Ihutai: year 2025
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2025-04-12
# 	Predict satellite image for date 2025-04-27
# 	Combine predictions and write conventions
# Ihutai: year 2026
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2026-02-01
# 	Predict satellite image for date 2026-03-18
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2016
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# LeftBank_Nov25: year 2017
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2017-02-20
# 	Predict satellite image for date 2017-10-13
# 	Predict satellite image for date 2017-11-27
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2018
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2018-09-18
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2019
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2019-07-10
# 	Predict satellite image for date 2019-08-24
# 	Predict satellite image for date 2019-11-20
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2020
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2020-05-15
# 	Predict satellite image for date 2020-05-30
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2021
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# LeftBank_Nov25: year 2022
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2022-05-23
# 	Predict satellite image for date 2022-08-06
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2023
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2023-10-22
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2024
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2024-02-04
# 	Predict satellite image for date 2024-10-11
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2025
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2025-12-13
# 	Combine predictions and write conventions
# LeftBank_Nov25: year 2026
# 	Predict for 4 satellite images
# 	Predict satellite image for date 2026-01-12
# 	Predict satellite image for date 2026-01-27
# 	Predict satellite image for date 2026-05-24
# 	Predict satellite image for date 2026-07-08
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2016
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# ThePoint_Nov25: year 2017
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2017-02-20
# 	Predict satellite image for date 2017-10-13
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2018
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2018-09-18
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2019
# 	Predict for 3 satellite images
# 	Predict satellite image for date 2019-07-10
# 	Predict satellite image for date 2019-08-24
# 	Predict satellite image for date 2019-11-20
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2020
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2020-05-15
# 	Predict satellite image for date 2020-05-30
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2021
# 	WARNING no satellite file to predict. Rerun the above cell if this is unexpected. Otherwise this indicates no suitable low-tide and low-cloud dates in the year.
# ThePoint_Nov25: year 2022
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2022-05-23
# 	Predict satellite image for date 2022-08-06
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2023
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2023-10-22
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2024
# 	Predict for 2 satellite images
# 	Predict satellite image for date 2024-02-04
# 	Predict satellite image for date 2024-10-11
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2025
# 	Predict for 1 satellite images
# 	Predict satellite image for date 2025-12-13
# 	Combine predictions and write conventions
# ThePoint_Nov25: year 2026
# 	Predict for 4 satellite images
# 	Predict satellite image for date 2026-01-12
# 	Predict satellite image for date 2026-01-27
# 	Predict satellite image for date 2026-05-24
# 	Predict satellite image for date 2026-07-08
# 	Combine predictions and write conventions
