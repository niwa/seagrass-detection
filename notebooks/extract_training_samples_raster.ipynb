# %% [markdown]
# # Extract training samples
# * Download low-tide cloud free satellite iamges closest to the UAV image collection
# * Sample the satellite image bands where appromximately a single UAV class

# %%
import pathlib
import numpy
import dask.distributed

module_path = pathlib.Path.cwd().parent / 'scripts'
import sys
if str(module_path) not in sys.path:
    sys.path.append(str(module_path))
import utils
import sentinel2
import training
import sampling

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Values to edit

# %%
sample_method = "sampling_2" # sampling_1 sampling_2
method_2_threshold = .8 # .95 .97 .98 .99 1.0
max_cloud_cover = 5 # percentage
low_tide_delta_hrs = 1
low_tide_delta_mins = 0

site_names = ["CatlinsLake", "CatlinsRiverMouth", "Childrens", "Duvauchelle", "Robinsons", "Takamatua", "Purau", "Ihutai",
              "IveyBay_Nov25", "IveyBay_Feb26", "LeftBank_Nov25", "LeftBank_Feb26", "Paremata_Nov25", "Paremata_Feb26",
              "Paremata_Feb25", "ThePoint_Nov25", "ThePoint_Feb26", "Takapuwahia_Nov25", "Takapuwahia_Feb26", "IveyBay_ThePoint_LeftBank_Oct24"]

# %% [markdown]
# # Cells to run

# %%
cluster = dask.distributed.LocalCluster()
client = dask.distributed.Client(cluster)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:56642' processes=4 threads=8, memory=31.73 GiB>

# %%
data_path = utils.get_data_path()
utils.create_data_folders()

training_labels_file = data_path / "ELF24505_ClassificationClasses.txt"
lowtide_search_range_file = data_path / "ELF24505_satellite_day_search_range.csv"
servey_dates_file = data_path / "ELF24505_SurveyDates.csv" 
uav_folder = data_path / "classified_uav"
samples_folder = utils.get_samples_path(sample_method=sample_method, method_2_threshold=method_2_threshold,
                                        max_cloud_cover=max_cloud_cover, low_tide_delta_hrs=low_tide_delta_hrs,
                                        low_tide_delta_mins=low_tide_delta_mins)

# %%
for site_name in site_names:
    sampling.sample_site_uav_raster(
        site_name=site_name,
        training_labels_file=training_labels_file,
        uav_folder=uav_folder,
        method_2_threshold=method_2_threshold,
        max_cloud_cover=max_cloud_cover,
        low_tide_delta_hrs=low_tide_delta_hrs,
        low_tide_delta_mins=low_tide_delta_mins
    )
# Out:
# Site CatlinsLake
# 	CatlinsLake_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site CatlinsRiverMouth
# 	CatlinsRiverMouth_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Childrens
# 	Childrens_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Duvauchelle
# 	Duvauchelle_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Robinsons
# 	Robinsons_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Takamatua
# 	Takamatua_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Purau
# 	Purau_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Ihutai
# 	Ihutai_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site IveyBay_Nov25
# 	IveyBay_Nov25_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site IveyBay_Feb26
# 	IveyBay_Feb26_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site LeftBank_Nov25
# 	LeftBank_Nov25_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site LeftBank_Feb26
# 	LeftBank_Feb26_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Paremata_Nov25
# 	Paremata_Nov25_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Paremata_Feb26
# 	Paremata_Feb26_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Paremata_Feb25
# 	Paremata_Feb25_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site ThePoint_Nov25
# 	ThePoint_Nov25_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site ThePoint_Feb26
# 	ThePoint_Feb26_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Takapuwahia_Nov25
# 	Takapuwahia_Nov25_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site Takapuwahia_Feb26
# 	Takapuwahia_Feb26_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# Site IveyBay_ThePoint_LeftBank_Oct24
# 	IveyBay_ThePoint_LeftBank_Oct24_training_data.nc already exists. Skipping. Delete if you want it regenerated.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 11
#       7         max_cloud_cover=max_cloud_cover,
#       8         low_tide_delta_hrs=low_tide_delta_hrs,
#       9         low_tide_delta_mins=low_tide_delta_mins
#      10     )
# ---> 11 counts_summary = sampling.site_sample_counts_by_class(sample_method=sample_method, method_2_threshold=method_2_threshold,
#      12                                                       max_cloud_cover=max_cloud_cover, low_tide_delta_hrs=low_tide_delta_hrs,
#      13                                                       low_tide_delta_mins=low_tide_delta_mins)
#
# File c:\Local\repos\seagrass-detection\scripts\sampling.py:567, in site_sample_counts_by_class(sample_method, method_2_threshold, max_cloud_cover, low_tide_delta_hrs, low_tide_delta_mins)
#     565     counts_summary.append(pandas.read_csv(site_summary_file))
#     566 # Into a summary across all sites
# --> 567 counts_summary = pandas.concat(counts_summary, keys=site_names).reset_index(
#     568     level=0, names="Site")[["Site","uav_class_name", "count"]].pivot(index="Site", columns="uav_class_name",values="count")
#     569 counts_summary = counts_summary.fillna(0)
#     570 counts_summary.to_csv(utils.get_samples_summary_file_path(sample_method, method_2_threshold,
#     571                                                           max_cloud_cover=max_cloud_cover,
#     572                                                           low_tide_delta_hrs=low_tide_delta_hrs, low_tide_delta_mins=low_tide_delta_mins))
#
# File ~\.conda\envs\seagrass\Lib\site-packages\pandas\core\reshape\concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File ~\.conda\envs\seagrass\Lib\site-packages\pandas\core\reshape\concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate

# %%
print(f"Samples located at {samples_folder}")
