# %% [markdown]
# # Extract training samples
# * Download low-tide cloud free satellite iamges closest to the UAV image collection
# * Sample the satellite image bands where appromximately a single UAV class

# %%
import pathlib
import numpy
import dask.distributed

module_path = pathlib.Path.cwd().parent / 'scripts'
import sys
if str(module_path) not in sys.path:
    sys.path.append(str(module_path))
import utils
import sentinel2
import training
import sampling

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Values to edit

# %%
sample_method = "sampling_2" # sampling_1 sampling_2
method_2_threshold = .8 # .95 .97 .98 .99 1.0
max_cloud_cover = 1 # percentage
low_tide_delta_hrs = 0
low_tide_delta_mins = 45

site_names = ["CatlinsLake", "CatlinsRiverMouth", "Childrens", "Duvauchelle", "Robinsons", "Takamatua", "Purau", "Ihutai",
              "IveyBay_Nov25", "IveyBay_Feb26", "LeftBank_Nov25", "LeftBank_Feb26", "Paremata_Nov25", "Paremata_Feb26",
              "Paremata_Feb25", "ThePoint_Nov25", "ThePoint_Feb26", "Takapuwahia_Nov25", "Takapuwahia_Feb26", "IveyBay_ThePoint_LeftBank_Oct24"]

# %% [markdown]
# # Cells to run

# %%
cluster = dask.distributed.LocalCluster()
client = dask.distributed.Client(cluster)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:58924' processes=4 threads=8, memory=31.73 GiB>

# %%
data_path = utils.get_data_path()
utils.create_data_folders()

training_labels_file = data_path / "ELF24505_ClassificationClasses.txt"
lowtide_search_range_file = data_path / "ELF24505_satellite_day_search_range.csv"
servey_dates_file = data_path / "ELF24505_SurveyDates.csv" 
uav_folder = data_path / "classified_uav"
samples_folder = utils.get_samples_path(sample_method=sample_method, method_2_threshold=method_2_threshold,
                                        max_cloud_cover=max_cloud_cover, low_tide_delta_hrs=low_tide_delta_hrs,
                                        low_tide_delta_mins=low_tide_delta_mins)

# %%
for site_name in site_names:
    sampling.sample_site_uav_raster(
        site_name=site_name,
        training_labels_file=training_labels_file,
        uav_folder=uav_folder,
        method_2_threshold=method_2_threshold,
        max_cloud_cover=max_cloud_cover,
        low_tide_delta_hrs=low_tide_delta_hrs,
        low_tide_delta_mins=low_tide_delta_mins
    )
# Out:
# Site CatlinsLake
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site CatlinsRiverMouth
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Childrens
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Duvauchelle
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Robinsons
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Takamatua
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Purau
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Ihutai
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site IveyBay_Nov25
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site IveyBay_Feb26
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site LeftBank_Nov25
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site LeftBank_Feb26
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Paremata_Nov25
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Paremata_Feb26
# Construct UAV class raster from UAV and Satellite imagery
# 	Class Seagrass
# 	Class Seagrass submerged
# 	Class Gracilaria
# 	Class Gracilaria submerged
# 	Class Ulva
# 	Class Cystophora
# 	Class Hormosira
# 	Class Brown algae mixed
# 	Class Submerged vegetation
# 	Class Microphytobenthos
# 	Class Green algae mixed
# 	Class Filamentous brown algae
# 	Class Ulva mats
# 	Class Saltmarsh
# 	Class Unvegetated
# 	Class Water
# 	Class Shadow
# 	Class Terrestrial
# 	Class Rock
# 	Class Glare
# 	Class Red algae mixed
# Site Paremata_Feb25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 for site_name in site_names:
# ----> 2     sampling.sample_site_uav_raster(
#       3         site_name=site_name,
#       4         training_labels_file=training_labels_file,
#       5         uav_folder=uav_folder,
#
# File c:\Local\repos\seagrass-detection\scripts\sampling.py:428, in sample_site_uav_raster(site_name, training_labels_file, uav_folder, max_cloud_cover, low_tide_delta_hrs, low_tide_delta_mins, method_2_threshold)
#     425 satellite_file = utils.get_satellite_path(site_name=site_name, low_tide_delta_hrs=low_tide_delta_hrs,
#     426                                           low_tide_delta_mins=low_tide_delta_mins, max_cloud_cover=max_cloud_cover)
#     427 if not satellite_file.exists():
# --> 428     raise ValueError(
#     429         f"Missing satellite image for site {site_name}. Try running `get_site_satellite` first. "
#     430          f"satellite_file: {satellite_file}")
#     431 satellite_data = utils.load_satellite(filename=satellite_file)
#     433 # Build and save the UAV class raster
#
# ValueError: Missing satellite image for site Paremata_Feb25. Try running `get_site_satellite` first. satellite_file: C:\Local\repos\seagrass-detection\data\satellite_images\low_tide_delta_30mins_max_cloud_percentage_1\Paremata_Feb25_sentinel-2.nc

# %%
print(f"Samples located at {samples_folder}")
# Out:
# Samples located at C:\Local\repos\seagrass-detection\data\training\low_tide_delta_30mins_max_cloud_percentage_1\sampling_2_80_percent
